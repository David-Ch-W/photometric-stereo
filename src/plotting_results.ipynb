# %%
# %%bash
# cd /Users/davidwu/Local/repositories/photometric-stereo/
# python src/main.py -i output_images -l light_directions.csv -o simulation_demo

# %%
SAVED_MATRIX = "/Users/davidwu/Local/repositories/photometric-stereo/simulation_demo.npy"

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Arial"

color_matrix = np.load(SAVED_MATRIX)

plt.figure(figsize=(5, 5))
plt.imshow(color_matrix)
plt.title(
    'Surface Normal Map\n(X -> Red, Y -> Green, Z -> Blue)', 
    fontsize=11, 
    fontweight='bold',
)
plt.show()
